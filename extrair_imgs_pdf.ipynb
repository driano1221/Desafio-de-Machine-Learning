# %% [markdown]
# <a href="https://colab.research.google.com/github/driano1221/Desafio-de-Machine-Learning/blob/main/extrair_imgs_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import fitz
import re
import cv2
import shutil
import os
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pdf_path = "/content/drive/MyDrive/Colab Notebooks/Cópia de PAT-RT-LAB-2612.21-001-Rev.03.pdf"
pasta_saida = "/content/drive/MyDrive/Colab Notebooks/saida"

# %%
doc = fitz.open(pdf_path)

# %%
id_pattern = re.compile(r"(?:Amostra|ID):\s*(.+)", re.IGNORECASE)

# %%
# --- --------------FILTROS E CONFIGURACOES ---------------------------
TERMOS_PARA_IGNORAR = ["TESTEMUNHO", "TSTEMUNHO", "TESTEMUNHHO", "TESTEMNHO", "FERNANDO"]
LOGO_LARGURA = 117
LOGO_ALTURA = 128
LARGURA_MINIMA = 300
ALTURA_MINIMA = 150
TAMANHO_MINIMO_KB = 20
pagina_limite = 1083
texto = "Depois do Ensaio"
DPI = 300 # Resolução para renderizar a imagem. DPI mais alto = melhor qualidade.

# %%
# Função auxiliar para unir retângulos (bounding boxes)

def unir_retangulos(rects):
    if not rects:
        return None
    final_rect = fitz.Rect(rects[0])
    for r in rects[1:]:
        final_rect.include_rect(r)
    return final_rect

# %%
# Função para agrupar imagens próximas

def agrupar_imagens_proximas(page, tolerancia=5):
    infos = page.get_image_info(xrefs=True)
    if not infos:
        return []

    rects = [fitz.Rect(info['bbox']) for info in infos]
    grupos = []

    while rects:
        base_rect = rects.pop(0)
        grupo_atual = [base_rect]
        i = 0
        while i < len(rects):
            r = rects[i]
            # Se um retângulo está próximo do grupo atual, junte-o
            if unir_retangulos(grupo_atual).intersects(r.irect + (-tolerancia, -tolerancia, tolerancia, tolerancia)):
                grupo_atual.append(rects.pop(i))
                i = 0  # Reinicia a verificação pois o grupo mudou
            else:
                i += 1
        grupos.append(unir_retangulos(grupo_atual))
    return grupos

# %%
os.makedirs(pasta_saida, exist_ok=True)

try:
    doc = fitz.open(pdf_path)
except Exception as e:
    print(f"Erro ao abrir o PDF: {e}")
    exit()

# %%
dados_extraidos = []
contador_salvas = 0
contador_ignoradas = 0

# %%
print(
    f"Iniciando extração com junção de imagens de: {os.path.basename(pdf_path)}")

for page_num in range(len(doc)):

    if page_num + 1 > pagina_limite:
        break

    page = doc.load_page(page_num)
    text = page.get_text()

    if texto.lower() in text.lower():

        id_match = id_pattern.search(text)

        if id_match:
            id_value = id_match.group(1).strip()

            ignorar_pagina = any(termo.upper() in id_value.upper()
                                for termo in TERMOS_PARA_IGNORAR)
            if ignorar_pagina:
                # print(f"  -> Página {page_num + 1} ignorada (contém termo proibido).")
                continue

            print(
                f"  --- ID '{id_value}' válido encontrado na página {page_num + 1}. Agrupando e renderizando imagens...")
            sanitized_id = re.sub(r'[\\/*?:"<>|\s]', '_', id_value)

            # --- NOVA LÓGICA ---
            # 1. Agrupa as imagens fatiadas
            areas_agrupadas = agrupar_imagens_proximas(page)

            # 2. Itera sobre as áreas agrupadas (imagens completas)
            for img_index, area_total in enumerate(areas_agrupadas, start=1):

                # 3. Renderiza a área completa como uma única imagem
                # Matriz de zoom para alta resolução
                mat = fitz.Matrix(DPI / 72, DPI / 72)
                pix = page.get_pixmap(clip=area_total, matrix=mat)

                # 4. Aplica os filtros na imagem JÁ RENDERIZADA E COMPLETA
                if (pix.width == LOGO_LARGURA and pix.height == LOGO_ALTURA):
                    contador_ignoradas += 1
                    continue

                if (pix.width < LARGURA_MINIMA or pix.height < ALTURA_MINIMA or len(pix.samples) < (TAMANHO_MINIMO_KB * 1024)):
                    contador_ignoradas += 1
                    continue

                # Se passou pelos filtros, salva
                # Salvar como PNG é mais seguro para pixmaps
                image_filename = f"pag_{page_num + 1:03}_ID_{sanitized_id}_img_{img_index}.png"
                output_path = os.path.join(pasta_saida, image_filename)
                pix.save(output_path)
                contador_salvas += 1

                dados_csv = {
                    'ID da Amostra': id_value,
                    'Pagina do PDF': page_num + 1,
                    'Nome do Arquivo': image_filename,
                    'Largura (px)': pix.width,
                    'Altura (px)': pix.height
                }

                dados_extraidos.append(dados_csv)

doc.close()
# Out:
# Iniciando extração com junção de imagens de: Cópia de PAT-RT-LAB-2612.21-001-Rev.03.pdf
#   --- ID 'ITA-FJ00001 - AM002' válido encontrado na página 39. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM002' válido encontrado na página 46. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM002' válido encontrado na página 53. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM003' válido encontrado na página 59. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM003' válido encontrado na página 66. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM003' válido encontrado na página 73. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM004' válido encontrado na página 81. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM004' válido encontrado na página 89. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM006' válido encontrado na página 98. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM006' válido encontrado na página 106. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM006' válido encontrado na página 113. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM007' válido encontrado na página 121. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM007' válido encontrado na página 128. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM008' válido encontrado na página 135. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM010' válido encontrado na página 145. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM010' válido encontrado na página 159. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM010' válido encontrado na página 172. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' válido encontrado na página 185. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' válido encontrado na página 195. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' válido encontrado na página 205. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM013' válido encontrado na página 212. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM013' válido encontrado na página 219. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM014' válido encontrado na página 226. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM015' válido encontrado na página 233. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM015' válido encontrado na página 241. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM001' válido encontrado na página 252. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM002' válido encontrado na página 263. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM003' válido encontrado na página 271. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM003' válido encontrado na página 281. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM003' válido encontrado na página 292. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM004' válido encontrado na página 303. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM004' válido encontrado na página 312. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' válido encontrado na página 322. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM008' válido encontrado na página 335. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM009' válido encontrado na página 346. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM010' válido encontrado na página 355. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM002' válido encontrado na página 361. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM002' válido encontrado na página 368. Agrupando e renderizando imagens...
#   --- ID 'TA-FJ00012 - AM002' válido encontrado na página 375. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM002' válido encontrado na página 382. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM003' válido encontrado na página 388. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM003' válido encontrado na página 395. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM003' válido encontrado na página 402. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 409. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 416. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 422. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 429. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 436. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 443. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 450. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' válido encontrado na página 457. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM005' válido encontrado na página 464. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM005' válido encontrado na página 471. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 478. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 485. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 492. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 499. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 506. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 513. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM008' válido encontrado na página 519. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM009' válido encontrado na página 527. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM010' válido encontrado na página 534. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM011' válido encontrado na página 541. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' válido encontrado na página 549. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' válido encontrado na página 557. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' válido encontrado na página 565. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' válido encontrado na página 573. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM012' válido encontrado na página 579. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM012' válido encontrado na página 585. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' válido encontrado na página 590. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' válido encontrado na página 599. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' válido encontrado na página 605. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' válido encontrado na página 612. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' válido encontrado na página 620. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM015' válido encontrado na página 628. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM015' válido encontrado na página 636. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM015' válido encontrado na página 643. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM016' válido encontrado na página 652. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0016' válido encontrado na página 661. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0016' válido encontrado na página 670. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' válido encontrado na página 676. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' válido encontrado na página 683. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' válido encontrado na página 690. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' válido encontrado na página 698. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' válido encontrado na página 707. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 714. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 723. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 732. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 740. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 749. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 757. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' válido encontrado na página 765. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM022' válido encontrado na página 773. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM022' válido encontrado na página 780. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' válido encontrado na página 787. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' válido encontrado na página 794. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' válido encontrado na página 801. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' válido encontrado na página 808. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0001' válido encontrado na página 815. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0001' válido encontrado na página 822. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM001' válido encontrado na página 828. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0001' válido encontrado na página 835. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM001' válido encontrado na página 842. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' válido encontrado na página 849. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' válido encontrado na página 856. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' válido encontrado na página 864. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' válido encontrado na página 870. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0003' válido encontrado na página 877. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0004' válido encontrado na página 885. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0007' válido encontrado na página 892. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM007' válido encontrado na página 899. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0007' válido encontrado na página 906. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM008' válido encontrado na página 913. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM008' válido encontrado na página 919. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' válido encontrado na página 926. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM010' válido encontrado na página 933. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM011' válido encontrado na página 940. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM013' válido encontrado na página 947. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM013' válido encontrado na página 954. Agrupando e renderizando imagens...
#   --- ID 'Registro:' válido encontrado na página 960. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0001' válido encontrado na página 966. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0002' válido encontrado na página 972. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0004' válido encontrado na página 978. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0005' válido encontrado na página 984. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0006' válido encontrado na página 990. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0010' válido encontrado na página 996. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0011' válido encontrado na página 1003. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0011' válido encontrado na página 1010. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0012' válido encontrado na página 1016. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0012' válido encontrado na página 1022. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0012' válido encontrado na página 1029. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0014' válido encontrado na página 1036. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0014' válido encontrado na página 1043. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0019' válido encontrado na página 1050. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0025' válido encontrado na página 1056. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0025' válido encontrado na página 1063. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0030' válido encontrado na página 1070. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0030' válido encontrado na página 1076. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0030' válido encontrado na página 1083. Agrupando e renderizando imagens...

# %%
df = pd.DataFrame(dados_extraidos)
csv_path = os.path.join(pasta_saida, "relatorio_extracao.csv")
df.to_csv(csv_path, index=False, encoding='utf-8-sig')
print("-" * 50)
print("Extração concluída com sucesso!")
print(f"Total de imagens completas salvas: {contador_salvas}")
print(f"Total de imagens ignoradas (logos/pequenas): {contador_ignoradas}")
print(f"As imagens foram salvas na pasta: '{pasta_saida}'")
# Out:
# --------------------------------------------------
# Extração concluída com sucesso!
# Total de imagens completas salvas: 534
# Total de imagens ignoradas (logos/pequenas): 139
# As imagens foram salvas na pasta: '/content/drive/MyDrive/Colab Notebooks/saida'

# %%
import fitz
import re
import cv2
import shutil
import os
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

pdf_path = "/content/drive/MyDrive/Colab Notebooks/Cópia de PAT-RT-LAB-2612.21-001-Rev.03.pdf"
pasta_saida = "/content/drive/MyDrive/Colab Notebooks/vistas_separadas"

doc = fitz.open(pdf_path)

id_pattern = re.compile(r"(?:Amostra|ID):\s*(.+)", re.IGNORECASE)
registro_pattern = re.compile(r"Registro:\s*(\d+)", re.IGNORECASE)  # Novo padrão para capturar o registro

# --- --------------FILTROS E CONFIGURACOES ---------------------------
TERMOS_PARA_IGNORAR = ["TESTEMUNHO", "TSTEMUNHO", "TESTEMUNHHO", "TESTEMNHO", "FERNANDO"]
LOGO_LARGURA = 117
LOGO_ALTURA = 128
LARGURA_MINIMA = 300
ALTURA_MINIMA = 150
TAMANHO_MINIMO_KB = 20
pagina_limite = 1083
texto = "Depois do Ensaio"
DPI = 300 # Resolução para renderizar a imagem. DPI mais alto = melhor qualidade.

# Função auxiliar para unir retângulos (bounding boxes)

def unir_retangulos(rects):
    if not rects:
        return None
    final_rect = fitz.Rect(rects[0])
    for r in rects[1:]:
        final_rect.include_rect(r)
    return final_rect

# Função para agrupar imagens próximas

def agrupar_imagens_proximas(page, tolerancia=5):
    infos = page.get_image_info(xrefs=True)
    if not infos:
        return []

    rects = [fitz.Rect(info['bbox']) for info in infos]
    grupos = []

    while rects:
        base_rect = rects.pop(0)
        grupo_atual = [base_rect]
        i = 0
        while i < len(rects):
            r = rects[i]
            # Se um retângulo está próximo do grupo atual, junte-o
            if unir_retangulos(grupo_atual).intersects(r.irect + (-tolerancia, -tolerancia, tolerancia, tolerancia)):
                grupo_atual.append(rects.pop(i))
                i = 0  # Reinicia a verificação pois o grupo mudou
            else:
                i += 1
        grupos.append(unir_retangulos(grupo_atual))
    return grupos

os.makedirs(pasta_saida, exist_ok=True)

try:
    doc = fitz.open(pdf_path)
except Exception as e:
    print(f"Erro ao abrir o PDF: {e}")
    exit()

dados_extraidos = []
contador_salvas = 0
contador_ignoradas = 0

print(
    f"Iniciando extração com junção de imagens de: {os.path.basename(pdf_path)}")

for page_num in range(len(doc)):

    if page_num + 1 > pagina_limite:
        break

    page = doc.load_page(page_num)
    text = page.get_text()

    if texto.lower() in text.lower():

        id_match = id_pattern.search(text)
        registro_match = registro_pattern.search(text)  # Busca pelo registro

        if id_match and registro_match:  # Agora precisa ter tanto ID quanto Registro
            id_value = id_match.group(1).strip()
            registro_value = registro_match.group(1).strip()  # Captura o número do registro

            ignorar_pagina = any(termo.upper() in id_value.upper()
                                for termo in TERMOS_PARA_IGNORAR)
            if ignorar_pagina:
                # print(f"  -> Página {page_num + 1} ignorada (contém termo proibido).")
                continue

            print(
                f"  --- ID '{id_value}' e Registro '{registro_value}' encontrados na página {page_num + 1}. Agrupando e renderizando imagens...")

            # --- NOVA LÓGICA ---
            # 1. Agrupa as imagens fatiadas
            areas_agrupadas = agrupar_imagens_proximas(page)

            # 2. Itera sobre as áreas agrupadas (imagens completas)
            for img_index, area_total in enumerate(areas_agrupadas, start=1):

                # 3. Renderiza a área completa como uma única imagem
                # Matriz de zoom para alta resolução
                mat = fitz.Matrix(DPI / 72, DPI / 72)
                pix = page.get_pixmap(clip=area_total, matrix=mat)

                # 4. Aplica os filtros na imagem JÁ RENDERIZADA E COMPLETA
                if (pix.width == LOGO_LARGURA and pix.height == LOGO_ALTURA):
                    contador_ignoradas += 1
                    continue

                if (pix.width < LARGURA_MINIMA or pix.height < ALTURA_MINIMA or len(pix.samples) < (TAMANHO_MINIMO_KB * 1024)):
                    contador_ignoradas += 1
                    continue

                # Se passou pelos filtros, salva com o novo formato de nome
                image_filename = f"{registro_value}_vista{img_index}.jpg"  # Novo formato
                output_path = os.path.join(pasta_saida, image_filename)

                # Salvar como JPG (convertendo do PNG)
                pix.save(output_path)
                contador_salvas += 1

                dados_csv = {
                    'ID da Amostra': id_value,
                    'Registro': registro_value,  # Adiciona o registro no CSV
                    'Pagina do PDF': page_num + 1,
                    'Nome do Arquivo': image_filename,
                    'Largura (px)': pix.width,
                    'Altura (px)': pix.height
                }

                dados_extraidos.append(dados_csv)

doc.close()

df = pd.DataFrame(dados_extraidos)
csv_path = os.path.join(pasta_saida, "relatorio_extracao.csv")
df.to_csv(csv_path, index=False, encoding='utf-8-sig')
print("-" * 50)
print("Extração concluída com sucesso!")
print(f"Total de imagens completas salvas: {contador_salvas}")
print(f"Total de imagens ignoradas (logos/pequenas): {contador_ignoradas}")
print(f"As imagens foram salvas na pasta: '{pasta_saida}'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Iniciando extração com junção de imagens de: Cópia de PAT-RT-LAB-2612.21-001-Rev.03.pdf
#   --- ID 'ITA-FJ00001 - AM002' e Registro '567' encontrados na página 39. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM002' e Registro '568' encontrados na página 46. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM002' e Registro '569' encontrados na página 53. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM003' e Registro '570' encontrados na página 59. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM003' e Registro '571' encontrados na página 66. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM003' e Registro '572' encontrados na página 73. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM004' e Registro '573' encontrados na página 81. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM004' e Registro '574' encontrados na página 89. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM006' e Registro '578' encontrados na página 98. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM006' e Registro '579' encontrados na página 106. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM006' e Registro '580' encontrados na página 113. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM007' e Registro '581' encontrados na página 121. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM007' e Registro '582' encontrados na página 128. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM008' e Registro '583' encontrados na página 135. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM010' e Registro '588' encontrados na página 145. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM010' e Registro '589' encontrados na página 159. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM010' e Registro '590' encontrados na página 172. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' e Registro '592' encontrados na página 185. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' e Registro '593' encontrados na página 195. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' e Registro '594' encontrados na página 205. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM013' e Registro '595' encontrados na página 212. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM013' e Registro '596' encontrados na página 219. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM014' e Registro '597' encontrados na página 226. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM015' e Registro '598' encontrados na página 233. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM015' e Registro '599' encontrados na página 241. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM001' e Registro '604' encontrados na página 252. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM002' e Registro '605' encontrados na página 263. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM003' e Registro '606' encontrados na página 271. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM003' e Registro '608' encontrados na página 281. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM003' e Registro '609' encontrados na página 292. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM004' e Registro '610' encontrados na página 303. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM004' e Registro '611' encontrados na página 312. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00001 - AM012' e Registro '617' encontrados na página 322. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM008' e Registro '618' encontrados na página 335. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM009' e Registro '620' encontrados na página 346. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00022 - AM010' e Registro '622' encontrados na página 355. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM002' e Registro '640' encontrados na página 361. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM002' e Registro '641' encontrados na página 368. Agrupando e renderizando imagens...
#   --- ID 'TA-FJ00012 - AM002' e Registro '643' encontrados na página 375. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM002' e Registro '644' encontrados na página 382. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM003' e Registro '645' encontrados na página 388. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM003' e Registro '646' encontrados na página 395. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM003' e Registro '649' encontrados na página 402. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '650' encontrados na página 409. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '651' encontrados na página 416. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '652' encontrados na página 422. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '653' encontrados na página 429. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '654' encontrados na página 436. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '655' encontrados na página 443. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '656' encontrados na página 450. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM004' e Registro '657' encontrados na página 457. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM005' e Registro '660' encontrados na página 464. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM005' e Registro '661' encontrados na página 471. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '676' encontrados na página 478. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '678' encontrados na página 485. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '679' encontrados na página 492. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '680' encontrados na página 499. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '681' encontrados na página 506. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '682' encontrados na página 513. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM008' e Registro '683' encontrados na página 519. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM009' e Registro '691' encontrados na página 527. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM010' e Registro '694' encontrados na página 534. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM011' e Registro '695' encontrados na página 541. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' e Registro '697' encontrados na página 549. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' e Registro '698' encontrados na página 557. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' e Registro '699' encontrados na página 565. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM011' e Registro '700' encontrados na página 573. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM012' e Registro '703' encontrados na página 579. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM012' e Registro '704' encontrados na página 585. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' e Registro '705' encontrados na página 590. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' e Registro '706' encontrados na página 599. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' e Registro '707' encontrados na página 605. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' e Registro '708' encontrados na página 612. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012- AM013' e Registro '709' encontrados na página 620. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM015' e Registro '712' encontrados na página 628. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM015' e Registro '713' encontrados na página 636. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM015' e Registro '714' encontrados na página 643. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM016' e Registro '715' encontrados na página 652. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0016' e Registro '716' encontrados na página 661. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0016' e Registro '717' encontrados na página 670. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' e Registro '718' encontrados na página 676. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' e Registro '719' encontrados na página 683. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' e Registro '720' encontrados na página 690. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' e Registro '721' encontrados na página 698. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM0017' e Registro '722' encontrados na página 707. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '733' encontrados na página 714. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '734' encontrados na página 723. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '735' encontrados na página 732. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '736' encontrados na página 740. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '737' encontrados na página 749. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '738' encontrados na página 757. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM020' e Registro '739' encontrados na página 765. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM022' e Registro '741' encontrados na página 773. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM022' e Registro '742' encontrados na página 780. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' e Registro '743' encontrados na página 787. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' e Registro '744' encontrados na página 794. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' e Registro '745' encontrados na página 801. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM023' e Registro '746' encontrados na página 808. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0001' e Registro '747' encontrados na página 815. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0001' e Registro '748' encontrados na página 822. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM001' e Registro '749' encontrados na página 828. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0001' e Registro '750' encontrados na página 835. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM001' e Registro '751' encontrados na página 842. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' e Registro '752' encontrados na página 849. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' e Registro '753' encontrados na página 856. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' e Registro '754' encontrados na página 864. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM002' e Registro '755' encontrados na página 870. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0003' e Registro '756' encontrados na página 877. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0004' e Registro '757' encontrados na página 885. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0007' e Registro '761' encontrados na página 892. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM007' e Registro '762' encontrados na página 899. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM0007' e Registro '763' encontrados na página 906. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM008' e Registro '764' encontrados na página 913. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM008' e Registro '765' encontrados na página 919. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00012 - AM008' e Registro '766' encontrados na página 926. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM010' e Registro '774' encontrados na página 933. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM011' e Registro '776' encontrados na página 940. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM013' e Registro '778' encontrados na página 947. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00008 - AM013' e Registro '780' encontrados na página 954. Agrupando e renderizando imagens...
#   --- ID 'Registro:' e Registro '782' encontrados na página 960. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0001' e Registro '783' encontrados na página 966. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0002' e Registro '784' encontrados na página 972. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0004' e Registro '787' encontrados na página 978. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0005' e Registro '788' encontrados na página 984. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0006' e Registro '789' encontrados na página 990. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0010' e Registro '793' encontrados na página 996. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0011' e Registro '794' encontrados na página 1003. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0011' e Registro '795' encontrados na página 1010. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0012' e Registro '796' encontrados na página 1016. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0012' e Registro '797' encontrados na página 1022. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0012' e Registro '798' encontrados na página 1029. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0014' e Registro '805' encontrados na página 1036. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0014' e Registro '806' encontrados na página 1043. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0019' e Registro '810' encontrados na página 1050. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0025' e Registro '820' encontrados na página 1056. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0025' e Registro '821' encontrados na página 1063. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0030' e Registro '831' encontrados na página 1070. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0030' e Registro '832' encontrados na página 1076. Agrupando e renderizando imagens...
#   --- ID 'ITA-FJ00003 - AM0030' e Registro '833' encontrados na página 1083. Agrupando e renderizando imagens...
# --------------------------------------------------
# Extração concluída com sucesso!
# Total de imagens completas salvas: 534
# Total de imagens ignoradas (logos/pequenas): 139
# As imagens foram salvas na pasta: '/content/drive/MyDrive/Colab Notebooks/vistas_separadas'

# %%
import fitz
import re
import os
import numpy as np
import cv2
from google.colab import drive

# Montar o Google Drive
drive.mount('/content/drive')

# Configurações específicas para a página 682 (registro 719)
pdf_path = "/content/drive/MyDrive/Colab Notebooks/Cópia de PAT-RT-LAB-2612.21-001-Rev.03.pdf"
pasta_saida = "/content/drive/MyDrive/Colab Notebooks/vistas_separadas_pagina_719"
pagina_alvo = 682  # Índice 681 corresponde à página 682

# Criar pasta de saída
os.makedirs(pasta_saida, exist_ok=True)

# Configurações técnicas
DPI = 300
MARGEM_LATERAL = 0.05  # 5% da largura da página como margem
NUM_VISTAS = 4  # Número de vistas esperadas

def crop_image(img):
    """Recorta as margens brancas de uma imagem."""
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        return img

    # Encontrar o maior contorno (a área principal)
    max_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(max_contour)

    # Adicionar pequena margem ao redor
    padding = 5
    x = max(0, x - padding)
    y = max(0, y - padding)
    w = min(img.shape[1] - x, w + 2*padding)
    h = min(img.shape[0] - y, h + 2*padding)

    return img[y:y+h, x:x+w]

print(f"Iniciando processamento ESPECÍFICO para a página 682 (índice {pagina_alvo})")

try:
    doc = fitz.open(pdf_path)
    print(f"PDF aberto com sucesso. Total de páginas: {len(doc)}")

    page = doc.load_page(pagina_alvo)
    print(f"Página {pagina_alvo + 1} carregada com sucesso")

    # Extrair texto para identificar o registro
    text = page.get_text()
    print(f"Texto extraído (primeiros 200 chars): {text[:200]}...")

    registro_pattern = re.compile(r"Registro:\s*(\d+)", re.IGNORECASE)
    registro_match = registro_pattern.search(text)

    if registro_match:
        registro_value = registro_match.group(1).strip()
        print(f"Registro identificado: {registro_value}")

        # Renderizar a página inteira em alta resolução
        mat = fitz.Matrix(DPI / 72, DPI / 72)
        pix = page.get_pixmap(matrix=mat)
        img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)
        if pix.n == 4:
            img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

        # Definir áreas de corte baseadas no layout padrão
        height, width = img.shape[:2]
        margin = int(width * MARGEM_LATERAL)
        vista_width = (width - 2 * margin) // NUM_VISTAS

        # Coordenadas finais para cada vista
        areas = [
            (margin, 0, vista_width, height),
            (margin + vista_width, 0, vista_width, height),
            (margin + 2 * vista_width, 0, vista_width, height),
            (margin + 3 * vista_width, 0, vista_width, height)
        ]

        for i, (x, y, w, h) in enumerate(areas, start=1):
            # Recortar a área
            vista = img[y:y+h, x:x+w]

            # Remover margens brancas
            vista_crop = crop_image(vista)

            # Salvar a vista
            image_filename = f"{registro_value}_vista{i}.jpg"
            output_path = os.path.join(pasta_saida, image_filename)
            cv2.imwrite(output_path, vista_crop)
            print(f"Vista {i} salva em: {output_path}")

    else:
        print("Registro não encontrado. Usando nome padrão...")
        registro_value = "719"
        # Processo similar usando nome padrão

    doc.close()
    print("\nProcessamento concluído!")
    print(f"Imagens salvas em: {pasta_saida}")

except Exception as e:
    print(f"Erro: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Iniciando processamento ESPECÍFICO para a página 682 (índice 682)
# PDF aberto com sucesso. Total de páginas: 1531
# Página 683 carregada com sucesso
# Texto extraído (primeiros 200 chars): Cliente:
# Vale S.A.
# ID:
# ITA-FJ00012 - AM0017
# Registro:
# 719
# Depois do Ensaio
# PATROL INVESTIGAÇÕES GEOTECNICAS LTDA.
# RELATÓRIO FOTOGRÁFICO
# ...
# Registro identificado: 719
# Vista 1 salva em: /content/drive/MyDrive/Colab Notebooks/vistas_separadas_pagina_719/719_vista1.jpg
# Vista 2 salva em: /content/drive/MyDrive/Colab Notebooks/vistas_separadas_pagina_719/719_vista2.jpg
# Vista 3 salva em: /content/drive/MyDrive/Colab Notebooks/vistas_separadas_pagina_719/719_vista3.jpg
# Vista 4 salva em: /content/drive/MyDrive/Colab Notebooks/vistas_separadas_pagina_719/719_vista4.jpg
#
# Processamento concluído!
# Imagens salvas em: /content/drive/MyDrive/Colab Notebooks/vistas_separadas_pagina_719

# %%
import pandas as pd
import os
from collections import Counter

# Caminho do arquivo CSV gerado
csv_path = "/content/drive/MyDrive/Colab Notebooks/vistas_separadas/relatorio_extracao.csv"
pasta_imagens = "/content/drive/MyDrive/Colab Notebooks/vistas_separadas"

# Verifica se o arquivo CSV existe
if not os.path.exists(csv_path):
    print("Arquivo CSV não encontrado. Execute primeiro a extração das imagens.")
else:
    # Lê o CSV
    df = pd.read_csv(csv_path)

    # Extrai o número da vista do nome do arquivo
    df['numero_vista'] = df['Nome do Arquivo'].str.extract(r'vista(\d+)\.jpg').astype(int)

    # Conta vistas por registro
    vistas_por_registro = df.groupby('Registro').agg({
        'numero_vista': ['min', 'max', 'count'],
        'ID da Amostra': 'first'
    }).reset_index()

    # Renomeia colunas
    vistas_por_registro.columns = ['Registro', 'Vista_Min', 'Vista_Max', 'Total_Vistas', 'ID_Amostra']

    print("📊 ESTATÍSTICAS DE VISTAS POR AMOSTRA")
    print("=" * 60)

    # Mostra estatísticas gerais
    total_amostras = len(vistas_por_registro)
    total_vistas = df.shape[0]

    print(f"Total de amostras processadas: {total_amostras}")
    print(f"Total de vistas extraídas: {total_vistas}")
    print()

    # Análise de distribuição de vistas
    distribuicao = vistas_por_registro['Total_Vistas'].value_counts().sort_index()
    print("📈 Distribuição de amostras por número de vistas:")
    for num_vistas, count in distribuicao.items():
        print(f"  {num_vistas} vistas: {count} amostras")
    print()

    # Verifica amostras com número incomum de vistas
    media_vistas = vistas_por_registro['Total_Vistas'].mean()
    print(f"📊 Média de vistas por amostra: {media_vistas:.2f}")
    print()

    # Mostra amostras com menor e maior número de vistas
    min_vistas = vistas_por_registro['Total_Vistas'].min()
    max_vistas = vistas_por_registro['Total_Vistas'].max()

    amostras_menos_vistas = vistas_por_registro[vistas_por_registro['Total_Vistas'] == min_vistas]
    amostras_mais_vistas = vistas_por_registro[vistas_por_registro['Total_Vistas'] == max_vistas]

    print(f"🔽 Amostras com menor número de vistas ({min_vistas}):")
    for _, row in amostras_menos_vistas.iterrows():
        print(f"  Registro: {row['Registro']} | ID: {row['ID_Amostra']} | Vistas: {row['Total_Vistas']}")
    print()

    print(f"🔼 Amostras com maior número de vistas ({max_vistas}):")
    for _, row in amostras_mais_vistas.iterrows():
        print(f"  Registro: {row['Registro']} | ID: {row['ID_Amostra']} | Vistas: {row['Total_Vistas']}")
    print()

    # Detalhamento por tipo de amostra (ID)
    print("📋 ANÁLISE POR TIPO DE AMOSTRA (ID)")
    print("=" * 60)

    vistas_por_id = df.groupby('ID da Amostra').agg({
        'Registro': 'nunique',
        'Nome do Arquivo': 'count'
    }).reset_index()
    vistas_por_id.columns = ['ID_Amostra', 'Qtd_Registros', 'Total_Vistas']

    # Calcula média de vistas por registro para cada ID
    media_por_id = df.groupby('ID da Amostra')['numero_vista'].agg(['min', 'max', 'mean', 'count']).reset_index()
    media_por_id.columns = ['ID_Amostra', 'Vista_Min', 'Vista_Max', 'Media_Vistas', 'Total_Vistas']

    print("Estatísticas por tipo de amostra:")
    for _, row in media_por_id.iterrows():
        print(f"  ID: {row['ID_Amostra']}")
        print(f"    Total de vistas: {row['Total_Vistas']}")
        print(f"    Faixa de vistas: {row['Vista_Min']} a {row['Vista_Max']}")
        print(f"    Média: {row['Media_Vistas']:.2f}")
        print()

    # Verifica se todas as amostras têm o mesmo número de vistas
    todos_iguais = len(distribuicao) == 1
    if todos_iguais:
        print("✅ Todas as amostras têm o mesmo número de vistas!")
    else:
        print("⚠️  ATENÇÃO: Nem todas as amostras têm o mesmo número de vistas!")
        print("   Verifique as amostras listadas acima.")

    print("\n" + "=" * 60)
    print("🔍 DETALHAMENTO COMPLETO POR REGISTRO")
    print("=" * 60)

    # Ordena por número de vistas (decrescente) para facilitar identificação de problemas
    vistas_por_registro = vistas_por_registro.sort_values('Registro', ascending=False)

    for _, row in vistas_por_registro.iterrows():
        print(f"Registro: {row['Registro']} | ID: {row['ID_Amostra']} | Vistas: {row['Total_Vistas']} "
              f"(de {row['Vista_Min']} a {row['Vista_Max']})")
# Out:
# 📊 ESTATÍSTICAS DE VISTAS POR AMOSTRA
# ============================================================
# Total de amostras processadas: 139
# Total de vistas extraídas: 534
#
# 📈 Distribuição de amostras por número de vistas:
#   1 vistas: 2 amostras
#   2 vistas: 4 amostras
#   3 vistas: 8 amostras
#   4 vistas: 125 amostras
#
# 📊 Média de vistas por amostra: 3.84
#
# 🔽 Amostras com menor número de vistas (1):
#   Registro: 589 | ID: ITA-FJ00001 - AM010 | Vistas: 1
#   Registro: 784 | ID: ITA-FJ00003 - AM0002 | Vistas: 1
#
# 🔼 Amostras com maior número de vistas (4):
#   Registro: 567 | ID: ITA-FJ00001 - AM002 | Vistas: 4
#   Registro: 568 | ID: ITA-FJ00001 - AM002 | Vistas: 4
#   Registro: 569 | ID: ITA-FJ00001 - AM002 | Vistas: 4
#   Registro: 570 | ID: ITA-FJ00001 - AM003 | Vistas: 4
#   Registro: 571 | ID: ITA-FJ00001 - AM003 | Vistas: 4
#   Registro: 572 | ID: ITA-FJ00001 - AM003 | Vistas: 4
#   Registro: 573 | ID: ITA-FJ00001 - AM004 | Vistas: 4
#   Registro: 574 | ID: ITA-FJ00001 - AM004 | Vistas: 4
#   Registro: 578 | ID: ITA-FJ00001 - AM006 | Vistas: 4
#   Registro: 579 | ID: ITA-FJ00001 - AM006 | Vistas: 4
#   Registro: 580 | ID: ITA-FJ00001 - AM006 | Vistas: 4
#   Registro: 581 | ID: ITA-FJ00001 - AM007 | Vistas: 4
#   Registro: 582 | ID: ITA-FJ00001 - AM007 | Vistas: 4
#   Registro: 583 | ID: ITA-FJ00001 - AM008 | Vistas: 4
#   Registro: 588 | ID: ITA-FJ00001 - AM010 | Vistas: 4
#   Registro: 590 | ID: ITA-FJ00001 - AM010 | Vistas: 4
#   Registro: 593 | ID: ITA-FJ00001 - AM012 | Vistas: 4
#   Registro: 594 | ID: ITA-FJ00001 - AM012 | Vistas: 4
#   Registro: 595 | ID: ITA-FJ00001 - AM013 | Vistas: 4
#   Registro: 596 | ID: ITA-FJ00001 - AM013 | Vistas: 4
#   Registro: 597 | ID: ITA-FJ00001 - AM014 | Vistas: 4
#   Registro: 598 | ID: ITA-FJ00001 - AM015 | Vistas: 4
#   Registro: 599 | ID: ITA-FJ00001 - AM015 | Vistas: 4
#   Registro: 604 | ID: ITA-FJ00022 - AM001 | Vistas: 4
#   Registro: 605 | ID: ITA-FJ00022 - AM002 | Vistas: 4
#   Registro: 606 | ID: ITA-FJ00022 - AM003 | Vistas: 4
#   Registro: 608 | ID: ITA-FJ00022 - AM003 | Vistas: 4
#   Registro: 609 | ID: ITA-FJ00022 - AM003 | Vistas: 4
#   Registro: 611 | ID: ITA-FJ00022 - AM004 | Vistas: 4
#   Registro: 617 | ID: ITA-FJ00001 - AM012 | Vistas: 4
#   Registro: 620 | ID: ITA-FJ00022 - AM009 | Vistas: 4
#   Registro: 622 | ID: ITA-FJ00022 - AM010 | Vistas: 4
#   Registro: 640 | ID: ITA-FJ00012 - AM002 | Vistas: 4
#   Registro: 641 | ID: ITA-FJ00012 - AM002 | Vistas: 4
#   Registro: 643 | ID: TA-FJ00012 - AM002 | Vistas: 4
#   Registro: 644 | ID: ITA-FJ00012 - AM002 | Vistas: 4
#   Registro: 645 | ID: ITA-FJ00012 - AM003 | Vistas: 4
#   Registro: 646 | ID: ITA-FJ00012 - AM003 | Vistas: 4
#   Registro: 649 | ID: ITA-FJ00012 - AM003 | Vistas: 4
#   Registro: 650 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 651 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 652 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 653 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 654 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 655 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 656 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 657 | ID: ITA-FJ00012 - AM004 | Vistas: 4
#   Registro: 660 | ID: ITA-FJ00012 - AM005 | Vistas: 4
#   Registro: 679 | ID: ITA-FJ00012 - AM008 | Vistas: 4
#   Registro: 680 | ID: ITA-FJ00012 - AM008 | Vistas: 4
#   Registro: 681 | ID: ITA-FJ00012 - AM008 | Vistas: 4
#   Registro: 683 | ID: ITA-FJ00012- AM008 | Vistas: 4
#   Registro: 691 | ID: ITA-FJ00012 - AM009 | Vistas: 4
#   Registro: 694 | ID: ITA-FJ00012- AM010 | Vistas: 4
#   Registro: 695 | ID: ITA-FJ00012 - AM011 | Vistas: 4
#   Registro: 697 | ID: ITA-FJ00012- AM011 | Vistas: 4
#   Registro: 698 | ID: ITA-FJ00012- AM011 | Vistas: 4
#   Registro: 699 | ID: ITA-FJ00012- AM011 | Vistas: 4
#   Registro: 700 | ID: ITA-FJ00012- AM011 | Vistas: 4
#   Registro: 703 | ID: ITA-FJ00012- AM012 | Vistas: 4
#   Registro: 704 | ID: ITA-FJ00012- AM012 | Vistas: 4
#   Registro: 705 | ID: ITA-FJ00012- AM013 | Vistas: 4
#   Registro: 706 | ID: ITA-FJ00012- AM013 | Vistas: 4
#   Registro: 707 | ID: ITA-FJ00012- AM013 | Vistas: 4
#   Registro: 709 | ID: ITA-FJ00012- AM013 | Vistas: 4
#   Registro: 712 | ID: ITA-FJ00012 - AM015 | Vistas: 4
#   Registro: 713 | ID: ITA-FJ00012 - AM015 | Vistas: 4
#   Registro: 714 | ID: ITA-FJ00012 - AM015 | Vistas: 4
#   Registro: 715 | ID: ITA-FJ00012 - AM016 | Vistas: 4
#   Registro: 716 | ID: ITA-FJ00012 - AM0016 | Vistas: 4
#   Registro: 717 | ID: ITA-FJ00012 - AM0016 | Vistas: 4
#   Registro: 718 | ID: ITA-FJ00012 - AM0017 | Vistas: 4
#   Registro: 720 | ID: ITA-FJ00012 - AM0017 | Vistas: 4
#   Registro: 721 | ID: ITA-FJ00012 - AM0017 | Vistas: 4
#   Registro: 722 | ID: ITA-FJ00012 - AM0017 | Vistas: 4
#   Registro: 733 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 734 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 735 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 736 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 737 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 738 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 739 | ID: ITA-FJ00012 - AM020 | Vistas: 4
#   Registro: 741 | ID: ITA-FJ00012 - AM022 | Vistas: 4
#   Registro: 742 | ID: ITA-FJ00012 - AM022 | Vistas: 4
#   Registro: 743 | ID: ITA-FJ00012 - AM023 | Vistas: 4
#   Registro: 744 | ID: ITA-FJ00012 - AM023 | Vistas: 4
#   Registro: 745 | ID: ITA-FJ00012 - AM023 | Vistas: 4
#   Registro: 747 | ID: ITA-FJ00008 - AM0001 | Vistas: 4
#   Registro: 748 | ID: ITA-FJ00008 - AM0001 | Vistas: 4
#   Registro: 749 | ID: ITA-FJ00008 - AM001 | Vistas: 4
#   Registro: 750 | ID: ITA-FJ00008 - AM0001 | Vistas: 4
#   Registro: 751 | ID: ITA-FJ00008 - AM001 | Vistas: 4
#   Registro: 752 | ID: ITA-FJ00008 - AM002 | Vistas: 4
#   Registro: 753 | ID: ITA-FJ00008 - AM002 | Vistas: 4
#   Registro: 754 | ID: ITA-FJ00008 - AM002 | Vistas: 4
#   Registro: 755 | ID: ITA-FJ00008 - AM002 | Vistas: 4
#   Registro: 756 | ID: ITA-FJ00008 - AM0003 | Vistas: 4
#   Registro: 757 | ID: ITA-FJ00008 - AM0004 | Vistas: 4
#   Registro: 761 | ID: ITA-FJ00008 - AM0007 | Vistas: 4
#   Registro: 762 | ID: ITA-FJ00008 - AM007 | Vistas: 4
#   Registro: 763 | ID: ITA-FJ00008 - AM0007 | Vistas: 4
#   Registro: 764 | ID: ITA-FJ00008 - AM008 | Vistas: 4
#   Registro: 765 | ID: ITA-FJ00008 - AM008 | Vistas: 4
#   Registro: 766 | ID: ITA-FJ00012 - AM008 | Vistas: 4
#   Registro: 774 | ID: ITA-FJ00008 - AM010 | Vistas: 4
#   Registro: 778 | ID: ITA-FJ00008 - AM013 | Vistas: 4
#   Registro: 780 | ID: ITA-FJ00008 - AM013 | Vistas: 4
#   Registro: 782 | ID: Registro: | Vistas: 4
#   Registro: 783 | ID: ITA-FJ00003 - AM0001 | Vistas: 4
#   Registro: 787 | ID: ITA-FJ00003 - AM0004 | Vistas: 4
#   Registro: 788 | ID: ITA-FJ00003 - AM0005 | Vistas: 4
#   Registro: 789 | ID: ITA-FJ00003 - AM0006 | Vistas: 4
#   Registro: 793 | ID: ITA-FJ00003 - AM0010 | Vistas: 4
#   Registro: 794 | ID: ITA-FJ00003 - AM0011 | Vistas: 4
#   Registro: 795 | ID: ITA-FJ00003 - AM0011 | Vistas: 4
#   Registro: 796 | ID: ITA-FJ00003 - AM0012 | Vistas: 4
#   Registro: 797 | ID: ITA-FJ00003 - AM0012 | Vistas: 4
#   Registro: 798 | ID: ITA-FJ00003 - AM0012 | Vistas: 4
#   Registro: 805 | ID: ITA-FJ00003 - AM0014 | Vistas: 4
#   Registro: 806 | ID: ITA-FJ00003 - AM0014 | Vistas: 4
#   Registro: 810 | ID: ITA-FJ00003 - AM0019 | Vistas: 4
#   Registro: 820 | ID: ITA-FJ00003 - AM0025 | Vistas: 4
#   Registro: 821 | ID: ITA-FJ00003 - AM0025 | Vistas: 4
#   Registro: 831 | ID: ITA-FJ00003 - AM0030 | Vistas: 4
#   Registro: 833 | ID: ITA-FJ00003 - AM0030 | Vistas: 4
#
# 📋 ANÁLISE POR TIPO DE AMOSTRA (ID)
# ============================================================
# Estatísticas por tipo de amostra:
#   ID: ITA-FJ00001 - AM002
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM003
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM004
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM006
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM007
#     Total de vistas: 8
#     Faixa de vistas: 1 a 5
#     Média: 3.00
#
#   ID: ITA-FJ00001 - AM008
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM010
#     Total de vistas: 9
#     Faixa de vistas: 2 a 5
#     Média: 3.33
#
#   ID: ITA-FJ00001 - AM012
#     Total de vistas: 15
#     Faixa de vistas: 2 a 5
#     Média: 3.40
#
#   ID: ITA-FJ00001 - AM013
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM014
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00001 - AM015
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0001
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0002
#     Total de vistas: 1
#     Faixa de vistas: 2 a 2
#     Média: 2.00
#
#   ID: ITA-FJ00003 - AM0004
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0005
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0006
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0010
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0011
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0012
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0014
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0019
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0025
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00003 - AM0030
#     Total de vistas: 11
#     Faixa de vistas: 2 a 5
#     Média: 3.36
#
#   ID: ITA-FJ00008 - AM0001
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM0003
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM0004
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM0007
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM001
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM002
#     Total de vistas: 16
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM007
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM008
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM010
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00008 - AM011
#     Total de vistas: 2
#     Faixa de vistas: 2 a 3
#     Média: 2.50
#
#   ID: ITA-FJ00008 - AM013
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM0016
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM0017
#     Total de vistas: 19
#     Faixa de vistas: 2 a 5
#     Média: 3.42
#
#   ID: ITA-FJ00012 - AM002
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM003
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM004
#     Total de vistas: 32
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM005
#     Total de vistas: 6
#     Faixa de vistas: 2 a 5
#     Média: 3.17
#
#   ID: ITA-FJ00012 - AM008
#     Total de vistas: 25
#     Faixa de vistas: 2 a 5
#     Média: 3.32
#
#   ID: ITA-FJ00012 - AM009
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM011
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM015
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM016
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM020
#     Total de vistas: 28
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM022
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012 - AM023
#     Total de vistas: 14
#     Faixa de vistas: 2 a 5
#     Média: 3.36
#
#   ID: ITA-FJ00012- AM008
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012- AM010
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012- AM011
#     Total de vistas: 16
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012- AM012
#     Total de vistas: 8
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00012- AM013
#     Total de vistas: 19
#     Faixa de vistas: 2 a 5
#     Média: 3.42
#
#   ID: ITA-FJ00022 - AM001
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00022 - AM002
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00022 - AM003
#     Total de vistas: 12
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00022 - AM004
#     Total de vistas: 7
#     Faixa de vistas: 2 a 5
#     Média: 3.29
#
#   ID: ITA-FJ00022 - AM008
#     Total de vistas: 2
#     Faixa de vistas: 2 a 3
#     Média: 2.50
#
#   ID: ITA-FJ00022 - AM009
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: ITA-FJ00022 - AM010
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: Registro:
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
#   ID: TA-FJ00012 - AM002
#     Total de vistas: 4
#     Faixa de vistas: 2 a 5
#     Média: 3.50
#
# ⚠️  ATENÇÃO: Nem todas as amostras têm o mesmo número de vistas!
#    Verifique as amostras listadas acima.
#
# ============================================================
# 🔍 DETALHAMENTO COMPLETO POR REGISTRO
# ============================================================
# Registro: 833 | ID: ITA-FJ00003 - AM0030 | Vistas: 4 (de 2 a 5)
# Registro: 832 | ID: ITA-FJ00003 - AM0030 | Vistas: 3 (de 2 a 4)
# Registro: 831 | ID: ITA-FJ00003 - AM0030 | Vistas: 4 (de 2 a 5)
# Registro: 821 | ID: ITA-FJ00003 - AM0025 | Vistas: 4 (de 2 a 5)
# Registro: 820 | ID: ITA-FJ00003 - AM0025 | Vistas: 4 (de 2 a 5)
# Registro: 810 | ID: ITA-FJ00003 - AM0019 | Vistas: 4 (de 2 a 5)
# Registro: 806 | ID: ITA-FJ00003 - AM0014 | Vistas: 4 (de 2 a 5)
# Registro: 805 | ID: ITA-FJ00003 - AM0014 | Vistas: 4 (de 2 a 5)
# Registro: 798 | ID: ITA-FJ00003 - AM0012 | Vistas: 4 (de 2 a 5)
# Registro: 797 | ID: ITA-FJ00003 - AM0012 | Vistas: 4 (de 2 a 5)
# Registro: 796 | ID: ITA-FJ00003 - AM0012 | Vistas: 4 (de 2 a 5)
# Registro: 795 | ID: ITA-FJ00003 - AM0011 | Vistas: 4 (de 2 a 5)
# Registro: 794 | ID: ITA-FJ00003 - AM0011 | Vistas: 4 (de 2 a 5)
# Registro: 793 | ID: ITA-FJ00003 - AM0010 | Vistas: 4 (de 2 a 5)
# Registro: 789 | ID: ITA-FJ00003 - AM0006 | Vistas: 4 (de 2 a 5)
# Registro: 788 | ID: ITA-FJ00003 - AM0005 | Vistas: 4 (de 2 a 5)
# Registro: 787 | ID: ITA-FJ00003 - AM0004 | Vistas: 4 (de 2 a 5)
# Registro: 784 | ID: ITA-FJ00003 - AM0002 | Vistas: 1 (de 2 a 2)
# Registro: 783 | ID: ITA-FJ00003 - AM0001 | Vistas: 4 (de 2 a 5)
# Registro: 782 | ID: Registro: | Vistas: 4 (de 2 a 5)
# Registro: 780 | ID: ITA-FJ00008 - AM013 | Vistas: 4 (de 2 a 5)
# Registro: 778 | ID: ITA-FJ00008 - AM013 | Vistas: 4 (de 2 a 5)
# Registro: 776 | ID: ITA-FJ00008 - AM011 | Vistas: 2 (de 2 a 3)
# Registro: 774 | ID: ITA-FJ00008 - AM010 | Vistas: 4 (de 2 a 5)
# Registro: 766 | ID: ITA-FJ00012 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 765 | ID: ITA-FJ00008 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 764 | ID: ITA-FJ00008 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 763 | ID: ITA-FJ00008 - AM0007 | Vistas: 4 (de 2 a 5)
# Registro: 762 | ID: ITA-FJ00008 - AM007 | Vistas: 4 (de 2 a 5)
# Registro: 761 | ID: ITA-FJ00008 - AM0007 | Vistas: 4 (de 2 a 5)
# Registro: 757 | ID: ITA-FJ00008 - AM0004 | Vistas: 4 (de 2 a 5)
# Registro: 756 | ID: ITA-FJ00008 - AM0003 | Vistas: 4 (de 2 a 5)
# Registro: 755 | ID: ITA-FJ00008 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 754 | ID: ITA-FJ00008 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 753 | ID: ITA-FJ00008 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 752 | ID: ITA-FJ00008 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 751 | ID: ITA-FJ00008 - AM001 | Vistas: 4 (de 2 a 5)
# Registro: 750 | ID: ITA-FJ00008 - AM0001 | Vistas: 4 (de 2 a 5)
# Registro: 749 | ID: ITA-FJ00008 - AM001 | Vistas: 4 (de 2 a 5)
# Registro: 748 | ID: ITA-FJ00008 - AM0001 | Vistas: 4 (de 2 a 5)
# Registro: 747 | ID: ITA-FJ00008 - AM0001 | Vistas: 4 (de 2 a 5)
# Registro: 746 | ID: ITA-FJ00012 - AM023 | Vistas: 2 (de 2 a 3)
# Registro: 745 | ID: ITA-FJ00012 - AM023 | Vistas: 4 (de 2 a 5)
# Registro: 744 | ID: ITA-FJ00012 - AM023 | Vistas: 4 (de 2 a 5)
# Registro: 743 | ID: ITA-FJ00012 - AM023 | Vistas: 4 (de 2 a 5)
# Registro: 742 | ID: ITA-FJ00012 - AM022 | Vistas: 4 (de 2 a 5)
# Registro: 741 | ID: ITA-FJ00012 - AM022 | Vistas: 4 (de 2 a 5)
# Registro: 739 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 738 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 737 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 736 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 735 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 734 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 733 | ID: ITA-FJ00012 - AM020 | Vistas: 4 (de 2 a 5)
# Registro: 722 | ID: ITA-FJ00012 - AM0017 | Vistas: 4 (de 2 a 5)
# Registro: 721 | ID: ITA-FJ00012 - AM0017 | Vistas: 4 (de 2 a 5)
# Registro: 720 | ID: ITA-FJ00012 - AM0017 | Vistas: 4 (de 2 a 5)
# Registro: 719 | ID: ITA-FJ00012 - AM0017 | Vistas: 3 (de 2 a 4)
# Registro: 718 | ID: ITA-FJ00012 - AM0017 | Vistas: 4 (de 2 a 5)
# Registro: 717 | ID: ITA-FJ00012 - AM0016 | Vistas: 4 (de 2 a 5)
# Registro: 716 | ID: ITA-FJ00012 - AM0016 | Vistas: 4 (de 2 a 5)
# Registro: 715 | ID: ITA-FJ00012 - AM016 | Vistas: 4 (de 2 a 5)
# Registro: 714 | ID: ITA-FJ00012 - AM015 | Vistas: 4 (de 2 a 5)
# Registro: 713 | ID: ITA-FJ00012 - AM015 | Vistas: 4 (de 2 a 5)
# Registro: 712 | ID: ITA-FJ00012 - AM015 | Vistas: 4 (de 2 a 5)
# Registro: 709 | ID: ITA-FJ00012- AM013 | Vistas: 4 (de 2 a 5)
# Registro: 708 | ID: ITA-FJ00012- AM013 | Vistas: 3 (de 2 a 4)
# Registro: 707 | ID: ITA-FJ00012- AM013 | Vistas: 4 (de 2 a 5)
# Registro: 706 | ID: ITA-FJ00012- AM013 | Vistas: 4 (de 2 a 5)
# Registro: 705 | ID: ITA-FJ00012- AM013 | Vistas: 4 (de 2 a 5)
# Registro: 704 | ID: ITA-FJ00012- AM012 | Vistas: 4 (de 2 a 5)
# Registro: 703 | ID: ITA-FJ00012- AM012 | Vistas: 4 (de 2 a 5)
# Registro: 700 | ID: ITA-FJ00012- AM011 | Vistas: 4 (de 2 a 5)
# Registro: 699 | ID: ITA-FJ00012- AM011 | Vistas: 4 (de 2 a 5)
# Registro: 698 | ID: ITA-FJ00012- AM011 | Vistas: 4 (de 2 a 5)
# Registro: 697 | ID: ITA-FJ00012- AM011 | Vistas: 4 (de 2 a 5)
# Registro: 695 | ID: ITA-FJ00012 - AM011 | Vistas: 4 (de 2 a 5)
# Registro: 694 | ID: ITA-FJ00012- AM010 | Vistas: 4 (de 2 a 5)
# Registro: 691 | ID: ITA-FJ00012 - AM009 | Vistas: 4 (de 2 a 5)
# Registro: 683 | ID: ITA-FJ00012- AM008 | Vistas: 4 (de 2 a 5)
# Registro: 682 | ID: ITA-FJ00012 - AM008 | Vistas: 3 (de 2 a 4)
# Registro: 681 | ID: ITA-FJ00012 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 680 | ID: ITA-FJ00012 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 679 | ID: ITA-FJ00012 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 678 | ID: ITA-FJ00012 - AM008 | Vistas: 3 (de 2 a 4)
# Registro: 676 | ID: ITA-FJ00012 - AM008 | Vistas: 3 (de 2 a 4)
# Registro: 661 | ID: ITA-FJ00012 - AM005 | Vistas: 2 (de 2 a 3)
# Registro: 660 | ID: ITA-FJ00012 - AM005 | Vistas: 4 (de 2 a 5)
# Registro: 657 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 656 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 655 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 654 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 653 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 652 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 651 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 650 | ID: ITA-FJ00012 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 649 | ID: ITA-FJ00012 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 646 | ID: ITA-FJ00012 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 645 | ID: ITA-FJ00012 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 644 | ID: ITA-FJ00012 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 643 | ID: TA-FJ00012 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 641 | ID: ITA-FJ00012 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 640 | ID: ITA-FJ00012 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 622 | ID: ITA-FJ00022 - AM010 | Vistas: 4 (de 2 a 5)
# Registro: 620 | ID: ITA-FJ00022 - AM009 | Vistas: 4 (de 2 a 5)
# Registro: 618 | ID: ITA-FJ00022 - AM008 | Vistas: 2 (de 2 a 3)
# Registro: 617 | ID: ITA-FJ00001 - AM012 | Vistas: 4 (de 2 a 5)
# Registro: 611 | ID: ITA-FJ00022 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 610 | ID: ITA-FJ00022 - AM004 | Vistas: 3 (de 2 a 4)
# Registro: 609 | ID: ITA-FJ00022 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 608 | ID: ITA-FJ00022 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 606 | ID: ITA-FJ00022 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 605 | ID: ITA-FJ00022 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 604 | ID: ITA-FJ00022 - AM001 | Vistas: 4 (de 2 a 5)
# Registro: 599 | ID: ITA-FJ00001 - AM015 | Vistas: 4 (de 2 a 5)
# Registro: 598 | ID: ITA-FJ00001 - AM015 | Vistas: 4 (de 2 a 5)
# Registro: 597 | ID: ITA-FJ00001 - AM014 | Vistas: 4 (de 2 a 5)
# Registro: 596 | ID: ITA-FJ00001 - AM013 | Vistas: 4 (de 2 a 5)
# Registro: 595 | ID: ITA-FJ00001 - AM013 | Vistas: 4 (de 2 a 5)
# Registro: 594 | ID: ITA-FJ00001 - AM012 | Vistas: 4 (de 2 a 5)
# Registro: 593 | ID: ITA-FJ00001 - AM012 | Vistas: 4 (de 2 a 5)
# Registro: 592 | ID: ITA-FJ00001 - AM012 | Vistas: 3 (de 2 a 4)
# Registro: 590 | ID: ITA-FJ00001 - AM010 | Vistas: 4 (de 2 a 5)
# Registro: 589 | ID: ITA-FJ00001 - AM010 | Vistas: 1 (de 2 a 2)
# Registro: 588 | ID: ITA-FJ00001 - AM010 | Vistas: 4 (de 2 a 5)
# Registro: 583 | ID: ITA-FJ00001 - AM008 | Vistas: 4 (de 2 a 5)
# Registro: 582 | ID: ITA-FJ00001 - AM007 | Vistas: 4 (de 1 a 4)
# Registro: 581 | ID: ITA-FJ00001 - AM007 | Vistas: 4 (de 2 a 5)
# Registro: 580 | ID: ITA-FJ00001 - AM006 | Vistas: 4 (de 2 a 5)
# Registro: 579 | ID: ITA-FJ00001 - AM006 | Vistas: 4 (de 2 a 5)
# Registro: 578 | ID: ITA-FJ00001 - AM006 | Vistas: 4 (de 2 a 5)
# Registro: 574 | ID: ITA-FJ00001 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 573 | ID: ITA-FJ00001 - AM004 | Vistas: 4 (de 2 a 5)
# Registro: 572 | ID: ITA-FJ00001 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 571 | ID: ITA-FJ00001 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 570 | ID: ITA-FJ00001 - AM003 | Vistas: 4 (de 2 a 5)
# Registro: 569 | ID: ITA-FJ00001 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 568 | ID: ITA-FJ00001 - AM002 | Vistas: 4 (de 2 a 5)
# Registro: 567 | ID: ITA-FJ00001 - AM002 | Vistas: 4 (de 2 a 5)

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 79.3 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.3

# %%
import os
import re
from collections import defaultdict

# Caminho da pasta
pasta = "/content/drive/MyDrive/Colab Notebooks/vistas_separadas"

# Dicionário para contar vistas por registro
registros = defaultdict(int)

# Listar arquivos e contar vistas
for arquivo in os.listdir(pasta):
    if arquivo.endswith('.jpg'):
        # Extrair número do registro (formato: 123_vista1.jpg)
        match = re.match(r'(\d+)_vista\d+\.jpg', arquivo)
        if match:
            registro = match.group(1)
            registros[registro] += 1

# Filtrar registros que não têm 4 vistas
print("📋 REGISTROS COM NÚMERO IRREGULAR DE VISTAS:")
print("=" * 50)

irregulares = [(reg, count) for reg, count in registros.items() if count != 4]

if irregulares:
    for registro, vistas in sorted(irregulares, key=lambda x: int(x[0])):
        print(f"Registro {registro}: {vistas} vistas")
    print(f"\nTotal de registros irregulares: {len(irregulares)}")
else:
    print("✅ Todos os registros têm 4 vistas!")

print(f"Total geral de registros: {len(registros)}")
# Out:
# 📋 REGISTROS COM NÚMERO IRREGULAR DE VISTAS:
# ==================================================
# Registro 589: 1 vistas
# Registro 592: 3 vistas
# Registro 610: 3 vistas
# Registro 618: 2 vistas
# Registro 661: 2 vistas
# Registro 676: 3 vistas
# Registro 678: 3 vistas
# Registro 682: 3 vistas
# Registro 708: 3 vistas
# Registro 719: 2 vistas
# Registro 746: 2 vistas
# Registro 776: 2 vistas
# Registro 784: 1 vistas
# Registro 832: 3 vistas
#
# Total de registros irregulares: 14
# Total geral de registros: 139
